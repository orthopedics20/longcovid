# %%
import pandas as pd

# %% [markdown]
# # Import Dataset

# %%
# Import RedcapExport.csv as df
df = pd.read_csv('RedcapExport.csv')
# Display the first 5 rows of the dataframe
df.head()
# Out:
#    record_id redcap_event_name  redcap_repeat_instrument  \
# 0          1     visit_2_arm_1                       NaN
# 1          1    baseline_arm_1                       NaN
# 2          2     visit_2_arm_1                       NaN
# 3          2    baseline_arm_1                       NaN
# 4          3     visit_2_arm_1                       NaN
#
#    redcap_repeat_instance  subjectid  subject_referral  covid_group  \
# 0                     NaN        NaN               NaN          NaN
# 1                     1.0        NaN               NaN          NaN
# 2                     NaN        NaN               NaN          NaN
# 3                     1.0        NaN               NaN          NaN
# 4                     NaN        NaN               NaN          NaN
#
#    interventiongroup  subject_information_complete  mmrc_score  ...  \
# 0                NaN                           NaN         0.0  ...
# 1                NaN                           NaN         2.0  ...
# ...
